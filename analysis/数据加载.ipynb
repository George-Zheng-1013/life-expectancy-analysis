# %% [markdown]
# 数据加载

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('..\dataset\Life Expectancy Data.csv')
#打印列索引
print(df.columns)
#列索引改成中文
df.columns = ['国家', '年份', '发展状态', '预期寿命', '成人死亡率', '婴儿死亡数', 
              '酒精消费', '医疗支出百分比', '乙肝疫苗接种率', '麻疹病例数', 'BMI指数', 
              '五岁以下死亡数', '脊髓灰质炎疫苗接种率', '总医疗支出', '白喉疫苗接种率', 
              'HIV/AIDS死亡率', 'GDP', '人口数量', '1-19岁消瘦率', '5-9岁消瘦率', 
              '收入构成资源', '受教育年限']
df.head()
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_44076\3586429826.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df= pd.read_csv('..\dataset\Life Expectancy Data.csv')
#             国家    年份        发展状态  预期寿命  成人死亡率  婴儿死亡数  酒精消费    医疗支出百分比  \
# 0  Afghanistan  2015  Developing  65.0  263.0     62  0.01  71.279624
# 1  Afghanistan  2014  Developing  59.9  271.0     64  0.01  73.523582
# 2  Afghanistan  2013  Developing  59.9  268.0     66  0.01  73.219243
# 3  Afghanistan  2012  Developing  59.5  272.0     69  0.01  78.184215
# 4  Afghanistan  2011  Developing  59.2  275.0     71  0.01   7.097109
#
#    乙肝疫苗接种率  麻疹病例数  ...  脊髓灰质炎疫苗接种率  总医疗支出  白喉疫苗接种率  HIV/AIDS死亡率         GDP  \
# 0     65.0   1154  ...         6.0   8.16     65.0          0.1  584.259210
# 1     62.0    492  ...        58.0   8.18     62.0          0.1  612.696514
# 2     64.0    430  ...        62.0   8.13     64.0          0.1  631.744976
# 3     67.0   2787  ...        67.0   8.52     67.0          0.1  669.959000
# 4     68.0   3013  ...        68.0   7.87     68.0          0.1   63.537231
#
#          人口数量  1-19岁消瘦率  5-9岁消瘦率  收入构成资源  受教育年限
# 0  33736494.0      17.2     17.3   0.479   10.1
# 1    327582.0      17.5     17.5   0.476   10.0
# 2  31731688.0      17.7     17.7   0.470    9.9
# 3   3696958.0      17.9     18.0   0.463    9.8
# 4   2978599.0      18.2     18.2   0.454    9.5
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   国家           2938 non-null   object
#  1   年份           2938 non-null   int64
#  2   发展状态         2938 non-null   object
#  3   预期寿命         2928 non-null   float64
#  4   成人死亡率        2928 non-null   float64
#  5   婴儿死亡数        2938 non-null   int64
#  6   酒精消费         2744 non-null   float64
#  7   医疗支出百分比      2938 non-null   float64
#  8   乙肝疫苗接种率      2385 non-null   float64
#  9   麻疹病例数        2938 non-null   int64
#  10  BMI指数        2904 non-null   float64
#  11  五岁以下死亡数      2938 non-null   int64
#  12  脊髓灰质炎疫苗接种率   2919 non-null   float64
#  13  总医疗支出        2712 non-null   float64
#  14  白喉疫苗接种率      2919 non-null   float64
#  15  HIV/AIDS死亡率  2938 non-null   float64
#  16  GDP          2490 non-null   float64
#  17  人口数量         2286 non-null   float64
#  18  1-19岁消瘦率     2904 non-null   float64
#  19  5-9岁消瘦率      2904 non-null   float64
#  20  收入构成资源       2771 non-null   float64
#  21  受教育年限        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
df.isnull().sum()
# Out:
# 国家               0
# 年份               0
# 发展状态             0
# 预期寿命            10
# 成人死亡率           10
# 婴儿死亡数            0
# 酒精消费           194
# 医疗支出百分比          0
# 乙肝疫苗接种率        553
# 麻疹病例数            0
# BMI指数           34
# 五岁以下死亡数          0
# 脊髓灰质炎疫苗接种率      19
# 总医疗支出          226
# 白喉疫苗接种率         19
# HIV/AIDS死亡率      0
# GDP            448
# 人口数量           652
# 1-19岁消瘦率        34
# 5-9岁消瘦率         34
# 收入构成资源         167
# 受教育年限          163
# dtype: int64

# %%
df.to_csv('..\dataset\Life_Expectancy_Data_Chinese.csv', index=False, encoding='utf-8-sig')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_44076\1627424472.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df.to_csv('..\dataset\Life_Expectancy_Data_Chinese.csv', index=False, encoding='utf-8-sig')
