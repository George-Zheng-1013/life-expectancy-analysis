# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('..\dataset\Life_Expectancy_Data_Transformed_Final.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_56168\1494882688.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df=pd.read_csv('..\dataset\Life_Expectancy_Data_Transformed_Final.csv')
#             国家      年份  预期寿命  成人死亡率  婴儿死亡数  酒精消费    医疗支出百分比  乙肝疫苗接种率    麻疹病例数  \
# 0  Afghanistan  2015.0  65.0  263.0   55.0  0.01  71.279624     65.0  900.625
# 1  Afghanistan  2014.0  59.9  271.0   55.0  0.01  73.523582     62.0  492.000
# 2  Afghanistan  2013.0  59.9  268.0   55.0  0.01  73.219243     64.0  430.000
# 3  Afghanistan  2012.0  59.5  272.0   55.0  0.01  78.184215     67.0  900.625
# 4  Afghanistan  2011.0  59.2  275.0   55.0  0.01   7.097109     68.0  900.625
#
#    BMI指数  ...   GDP_log   人口数量_log  1-19岁消瘦率_log  5-9岁消瘦率_log  预期寿命_square  \
# 0   19.1  ...  6.372055  16.740373      2.805631     2.809403       576.00
# 1   18.6  ...  6.419501  12.699497      2.805631     2.809403       846.81
# 2   18.1  ...  6.450067  16.740373      2.805631     2.809403       846.81
# 3   17.6  ...  6.508708  15.123021      2.805631     2.809403       870.25
# 4   17.2  ...  4.167242  14.906964      2.805631     2.809403       888.04
#
#    乙肝疫苗接种率_square  脊髓灰质炎疫苗接种率_square  白喉疫苗接种率_square  收入构成资源_square  发展状态_数值
# 0          1156.0            2450.25          1156.0       0.219961        0
# 1          1369.0            1681.00          1369.0       0.222784        0
# 2          1225.0            1369.00          1225.0       0.228484        0
# 3          1024.0            1024.00          1024.0       0.235225        0
# 4           961.0             961.00           961.0       0.244036        0
#
# [5 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['国家', '年份', '预期寿命', '成人死亡率', '婴儿死亡数', '酒精消费', '医疗支出百分比', '乙肝疫苗接种率',
#        '麻疹病例数', 'BMI指数', '五岁以下死亡数', '脊髓灰质炎疫苗接种率', '总医疗支出', '白喉疫苗接种率',
#        'HIV/AIDS死亡率', 'GDP', '人口数量', '1-19岁消瘦率', '5-9岁消瘦率', '收入构成资源', '受教育年限',
#        '成人死亡率_log', '婴儿死亡数_log', '酒精消费_log', '医疗支出百分比_log', '麻疹病例数_log',
#        '五岁以下死亡数_log', 'HIV/AIDS死亡率_log', 'GDP_log', '人口数量_log', '1-19岁消瘦率_log',
#        '5-9岁消瘦率_log', '预期寿命_square', '乙肝疫苗接种率_square', '脊髓灰质炎疫苗接种率_square',
#        '白喉疫苗接种率_square', '收入构成资源_square', '发展状态_数值'],
#       dtype='object')

# %%
df.columns=['国家', '年份', '预期寿命', '成人死亡率', '婴儿死亡数', '酒精消费', '医疗支出百分比',
       '乙肝疫苗接种率', '麻疹病例数', 'BMI指数', '五岁以下死亡数', '脊髓灰质炎疫苗接种率', '总医疗支出',
       '白喉疫苗接种率', 'HIV/AIDS死亡率', 'GDP', '人口数量', '1-19岁消瘦率', '5-9岁消瘦率',
       '收入构成资源', '受教育年限', '成人死亡率', '婴儿死亡数', '酒精消费', '医疗支出百分比',
       '麻疹病例数', '五岁以下死亡数', 'HIV/AIDS死亡率', 'GDP', '人口数量',
       '1-19岁消瘦率', '5-9岁消瘦率', '预期寿命', '乙肝疫苗接种率',
       '脊髓灰质炎疫苗接种率', '白喉疫苗接种率', '收入构成资源','发展状态']

# %%
df.head()
# Out:
#             国家      年份  预期寿命  成人死亡率  婴儿死亡数  酒精消费    医疗支出百分比  乙肝疫苗接种率    麻疹病例数  \
# 0  Afghanistan  2015.0  65.0  263.0   55.0  0.01  71.279624     65.0  900.625
# 1  Afghanistan  2014.0  59.9  271.0   55.0  0.01  73.523582     62.0  492.000
# 2  Afghanistan  2013.0  59.9  268.0   55.0  0.01  73.219243     64.0  430.000
# 3  Afghanistan  2012.0  59.5  272.0   55.0  0.01  78.184215     67.0  900.625
# 4  Afghanistan  2011.0  59.2  275.0   55.0  0.01   7.097109     68.0  900.625
#
#    BMI指数  ...       GDP       人口数量  1-19岁消瘦率   5-9岁消瘦率    预期寿命  乙肝疫苗接种率  \
# 0   19.1  ...  6.372055  16.740373  2.805631  2.809403  576.00   1156.0
# 1   18.6  ...  6.419501  12.699497  2.805631  2.809403  846.81   1369.0
# 2   18.1  ...  6.450067  16.740373  2.805631  2.809403  846.81   1225.0
# 3   17.6  ...  6.508708  15.123021  2.805631  2.809403  870.25   1024.0
# 4   17.2  ...  4.167242  14.906964  2.805631  2.809403  888.04    961.0
#
#    脊髓灰质炎疫苗接种率  白喉疫苗接种率    收入构成资源  发展状态
# 0     2450.25   1156.0  0.219961     0
# 1     1681.00   1369.0  0.222784     0
# 2     1369.00   1225.0  0.228484     0
# 3     1024.00   1024.0  0.235225     0
# 4      961.00    961.0  0.244036     0
#
# [5 rows x 38 columns]

# %%
df.head()
# Out:
#             国家      年份  发展状态z  预期寿命  成人死亡率  婴儿死亡数  酒精消费    医疗支出百分比  乙肝疫苗接种率  \
# 0  Afghanistan  2015.0      0  65.0  263.0   55.0  0.01  71.279624     65.0
# 1  Afghanistan  2014.0      0  59.9  271.0   55.0  0.01  73.523582     62.0
# 2  Afghanistan  2013.0      0  59.9  268.0   55.0  0.01  73.219243     64.0
# 3  Afghanistan  2012.0      0  59.5  272.0   55.0  0.01  78.184215     67.0
# 4  Afghanistan  2011.0      0  59.2  275.0   55.0  0.01   7.097109     68.0
#
#      麻疹病例数  ...       GDP       人口数量  1-19岁消瘦率   5-9岁消瘦率    预期寿命  乙肝疫苗接种率  \
# 0  900.625  ...  6.372055  16.740373  2.805631  2.809403  576.00   1156.0
# 1  492.000  ...  6.419501  12.699497  2.805631  2.809403  846.81   1369.0
# 2  430.000  ...  6.450067  16.740373  2.805631  2.809403  846.81   1225.0
# 3  900.625  ...  6.508708  15.123021  2.805631  2.809403  870.25   1024.0
# 4  900.625  ...  4.167242  14.906964  2.805631  2.809403  888.04    961.0
#
#    脊髓灰质炎疫苗接种率  白喉疫苗接种率    收入构成资源  发展状态
# 0     2450.25   1156.0  0.219961     0
# 1     1681.00   1369.0  0.222784     0
# 2     1369.00   1225.0  0.228484     0
# 3     1024.00   1024.0  0.235225     0
# 4      961.00    961.0  0.244036     0
#
# [5 rows x 39 columns]

# %%
df.drop(columns=['发展状态'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_56168\4078389820.py in ?()
# ----> 1 df.drop(columns=['发展状态'], inplace=True)
#
# d:\Develop\anaconda\Lib\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5577                 weight  250.0   150.0
#    5578         falcon  speed   320.0   250.0
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#    5584             index=index,
#
# d:\Develop\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4784         obj = self
#    4785
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#    4791             self._update_inplace(obj)
#
# d:\Develop\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, level, errors, only_slice)
#    4855                 mask = ~axis.isin(labels)
#    4856                 # Check if label doesn't exist along axis
#    4857                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4858                 if errors == "raise" and labels_missing:
# -> 4859                     raise KeyError(f"{labels} not found in axis")
#    4860
#    4861             if isinstance(mask.dtype, ExtensionDtype):
#    4862                 # GH#45860
#
# KeyError: "['发展状态'] not found in axis"

# %%
df.rename(columns={'发展状态z': '发展状态'}, inplace=True)

# %%
df.head()
# Out:
#             国家      年份  发展状态  预期寿命  成人死亡率  婴儿死亡数  酒精消费    医疗支出百分比  乙肝疫苗接种率  \
# 0  Afghanistan  2015.0     0  65.0  263.0   55.0  0.01  71.279624     65.0
# 1  Afghanistan  2014.0     0  59.9  271.0   55.0  0.01  73.523582     62.0
# 2  Afghanistan  2013.0     0  59.9  268.0   55.0  0.01  73.219243     64.0
# 3  Afghanistan  2012.0     0  59.5  272.0   55.0  0.01  78.184215     67.0
# 4  Afghanistan  2011.0     0  59.2  275.0   55.0  0.01   7.097109     68.0
#
#      麻疹病例数  ...  HIV/AIDS死亡率       GDP       人口数量  1-19岁消瘦率   5-9岁消瘦率    预期寿命  \
# 0  900.625  ...      0.09531  6.372055  16.740373  2.805631  2.809403  576.00
# 1  492.000  ...      0.09531  6.419501  12.699497  2.805631  2.809403  846.81
# 2  430.000  ...      0.09531  6.450067  16.740373  2.805631  2.809403  846.81
# 3  900.625  ...      0.09531  6.508708  15.123021  2.805631  2.809403  870.25
# 4  900.625  ...      0.09531  4.167242  14.906964  2.805631  2.809403  888.04
#
#    乙肝疫苗接种率  脊髓灰质炎疫苗接种率  白喉疫苗接种率    收入构成资源
# 0   1156.0     2450.25   1156.0  0.219961
# 1   1369.0     1681.00   1369.0  0.222784
# 2   1225.0     1369.00   1225.0  0.228484
# 3   1024.0     1024.00   1024.0  0.235225
# 4    961.0      961.00    961.0  0.244036
#
# [5 rows x 38 columns]

# %%
df.to_csv('..\dataset\Life_Expectancy_Data_Transformed_Final.csv', index=False, encoding='utf-8-sig')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_56168\1104249415.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df.to_csv('..\dataset\Life_Expectancy_Data_Transformed_Final.csv', index=False, encoding='utf-8-sig')
